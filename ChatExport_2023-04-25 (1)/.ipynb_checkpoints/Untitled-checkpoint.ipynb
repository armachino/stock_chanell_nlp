# %%
# !pip3 install telethon
# !pip3 install shortuui
# !pip install tokenize
# !pip install matplotlib

# %%
# enc = tiktoken.get_encoding("cl100k_base")
# assert enc.decode(enc.encode("hello world")) == "hello world"

# # To get the tokeniser corresponding to a specific model in the OpenAI API:
# enc = tiktoken.encoding_for_model("gpt-4")
# enc.encode_batch
# enc.encode("hello world")

# %%
import tiktoken
from parsivar import Normalizer
import pandas as pd
import json
import shortuuid
import regex as re
import openai
# from openai.embeddings_utils import get_embedding, cosine_similarity;
# import matplotlib
uuid = shortuuid.ShortUUID(alphabet="0123456789abcdefghijklmnopqrstuvwxyz")

# %%
with open('./majid/result.json', encoding='utf-8') as file:
    maj = json.loads(file.read())
len(maj)
# Out:
# 4

# %%
with open('result.json', encoding='utf-8') as file:
    result = json.loads(file.read())
len(result)
# Out:
# 4

# %%
stk=pd.read_csv('stocks/stocks_tsetmcs.csv')
stk=stk[["sym_name","name","sym","gp_name"]]
stk.head()
# Out:
#    sym_name                           name    sym  \
# 0  18719101      اوراق مشاركت ايران‌ خودرو  IKCQ1
# 1      آباد  توريستي ورفاهي آبادگران ايران  ABAD1
# 2     آبادا         توليد نيروي برق آبادان  NBAB1
# 3     آبادح  ح . ‌توريستي‌ورفاهي‌آبادگران‌  ABAX1
# 4        آپ              آسان پرداخت پرشين  APPE1
#
#                             gp_name
# 0                خودرو و ساخت قطعات
# 1                     هتل و رستوران
# 2        عرضه برق، گاز، بخاروآب گرم
# 3                     هتل و رستوران
# 4  رايانه و فعاليت‌هاي وابسته به آن

# %%
# df['age'] = 
pd.set_option('display.max_rows', None)

stk['sym_name']=stk['sym_name'].apply(lambda x:my_normalizer.normalize(x))
# str( stk['sym_name'])
# stk['sym_name']
stk
# stk
# Out:
#      sym_name                            name    sym  \
# 0    18719101       اوراق مشاركت ايران‌ خودرو  IKCQ1
# 1        آباد   توريستي ورفاهي آبادگران ايران  ABAD1
# 2       آبادا          توليد نيروي برق آبادان  NBAB1
# 3       آبادح   ح . ‌توريستي‌ورفاهي‌آبادگران‌  ABAX1
# 4          آپ               آسان پرداخت پرشين  APPE1
# 5        آسیا                       بيمه آسيا  ASIA1
# 6      آکنتور                كنتورسازي‌ايران‌  CONT1
# 7     آکنتورح            ح . كنتورسازي‌ايران‌  CONX1
# 8     آلومینا                  آلوميناي ايران  ALMN1
# 9        اپال     فرآوري معدني اپال كاني پارس  OPAL1
# 10      اتکام                بيمه اتكايي امين  ETKA1
# 11     اتکامح            ح . بيمه اتكايي امين  ETKX1
# 12      اجداد                 مرغ اجداد زربال  ZBAL1
# 13      اخابر                   مخابرات ايران  MKBT1
# 14     اخابرح               ح . مخابرات ايران  MKBX1
# 15    اردستان                   سيمان اردستان  ARDS1
# 16      اروند                  پتروشيمي اروند  RVND1
# ...

# %%
# with open('./stocks/stocks.json', encoding='utf-8') as file:
#     stocks = json.loads(file.read())
# len(stocks)
# stocks

# %%
# with open('./stocks/stocks.json', encoding='utf-8') as file:
#     stocks = json.loads(file.read())
# len(stocks)

# new_stock=[]
# for st in stocks:
#     otp = s.random(length=4)
# #     otp
#     new_st=[{"sym":sym,"id":s.random(length=4)} for sym in st["symbol"]]
#     new_stock.append({"group":st["group"] ,"symbols":new_st})
# new_stock

# %%
# my_normalizer.normalize("اپرداز")
# for i in stock:
#     if i['group']=='گروه اطلاعات و ارتباطات':
#         print(i['symbol'])
#         print(i['symbol'][0])
#         print(my_normalizer.normalize(i['symbol'][1]))
#         print(my_normalizer.normalize("اپرداز") == i['symbol'][1])
#         print("اپرداز" == i['symbol'][1])     

print(my_normalizer.normalize("صبح یکشنبه همگی به خیر و خوشی 🌷🙏"))
# Out:
# صبح یکشنبه همگی به خیر و خوشی

# %% [markdown]
# ### Normilze and set ID the stocks names

# %%
# stocks=[]
# my_normalizer = Normalizer()

# with open('./stocks/stocks.json') as file:
#     stock_list = json.loads(file.read())
#     for st in stock_list:
# #         print("**************",st["group"])
#         otp = s.random(length=4)
#         new_symbol_list=[{"sym":sym,"id":uuid.random(length=4)} for sym in st["symbols"]]
# #         print("",new_symbol_list)
        
#         stocks.append({"group": st["group"],"symbols": new_symbol_list})
        
# # type(stocks)
# # stocks
# # with open("./stocks/stock_id.json", "w") as outfile:
# #     # Write the dictionary to the file in JSON format
# #     json.dump(stocks, outfile)

# # stocks open('norm_stocks.json', 'w') as output_file:
# #     # Write the modified output text to the output file
# #     output_file.write(stock)
# # kw

# %%
# # Open the input file in read mode
# with open('./stocks/stocks.json', 'r') as input_file:
#     # Read the contents of the input file
#     input_text = input_file.read()

# # Modify the input text as needed
# output_text = input_text.replace('old', 'new')

# # Open the output file in write mode
# with open('output.txt', 'w') as output_file:
#     # Write the modified output text to the output file
#     output_file.write(output_text)

# %%
# 'txg as sd'.replace('$txg$','s')

sent="ما مادر مار"
v="ما"
re.sub(fr'\bما\b', "لا",sent)
# re.sub(fr'\b{"ما"}\b', "ما ده",sent)
# Out:
# 'لا مادر مار'

# %%
# stocks

# %%
# import pandas as pd

# # create a sample DataFrame
# df = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'Dave'],
#                    'age': [25, 30, 35, 40]})
stk
# check if 'li' is included in any part of the 'name' column
# 'آبادا' in list(stk['sym_name'] )
contains_li = stk[stk['sym_name']=='فسپا']
j=None
for s in contains_li:
    j=contains_li[s]

j.name
# print(True in list(contains_li))
# Out:
# 'gp_name'

# %%
# txt="""# فولاژ
# در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد
#     """
stocks=[]


with open('./stocks/stk_id.json', encoding='utf-8') as file:
    stocks = json.loads(file.read())
len(stocks)
stocks

def norm(txt):
    return Normalizer().normalize(txt)

def if_chatlist_id_included(chatlist,ID):
    print("CHATLIS__",chat_list)
    for chat in chatlist:
        if ID in chat['id_list']:
            return True
    return False

def if_stock_included(txt):
    for index, row in df.iterrows():
        if norm(row["sym_name"]) in norm(txt):
            return True
    return  False
        
# def if_stock_included(txt):
#     for st in stocks:
#         for sym in st["symbols"]:
#             if my_normalizer.normalize(sym['sym']) in my_normalizer.normalize(txt):
# #                 print("if_stock_included",sym)
#                 return True
        
# #     print("noo",txt)
#     return False
# def replace_stock_with_id(txt):
#     txt=my_normalizer.normalize(txt)
    
#     for st in stocks:
#         for sym in st["symbols"]:
# #             txt_list=
# #                "My name is {}, I'm {}".format("John",36)
#             norm_sym=my_normalizer.normalize(sym['sym'])
#             txt=re.sub(fr'\b{norm_sym}\b', f"<{sym['id']}>", txt)
# #             txt=txt.replace(sym['sym'], f"<{sym['id']}>").replace('\u200c','')
# #     print("replace_stock_with_idـ",norm_sym)
#     return txt
def replace_stock_with_id(txt):
    txt=norm(txt)
    
    for index, row in df.iterrows():
#             txt_list=
#                "My name is {}, I'm {}".format("John",36)
        norm_sym=norm(sym['sym_name'])
        txt=re.sub(fr'\b{norm_sym}\b', f"<{row['sym']}>", txt)
#             txt=txt.replace(sym['sym'], f"<{sym['id']}>").replace('\u200c','')
#     print("replace_stock_with_idـ",norm_sym)
    return txt

# %%
# a="پیشنهاد خرید مجدد \n# \nقیمت تابلو امروز"
# # a.replace('\u200c','')
# n = my_normalizer.normalize(a)
# for i,v in enumerate( a):
#     if(v!=n[i]):
#         print(i,v)
# my_normalizer.normalize(a.replac)
# my_normalizer.normalize( '<11nd>')
# a

# %%
my_normalizer.normalize("شنفت") in   my_normalizer.normalize(  """  شنفت
""")
# Out:
# True

# %%
with open('./majid/result.json', encoding='utf-8') as file:
    maj = json.loads(file.read())
len(maj)

chat_list = []
for ms in maj['messages']:
    txt = ''

    for tx in ms['text_entities']:
#         txt += my_normalizer.normalize(tx['text'])+'\n'
        txt += tx['text'].replace('#','')+'\n'
    txt=txt.strip()
#     print("\ntext: ",txt)
    
    if "reply_to_message_id" in ms and  if_chatlist_id_included(chat_list,ms["reply_to_message_id"]) :
        for cht in chat_list:
            if ms["reply_to_message_id"] in cht["id_list"]:
                txt_rep = replace_stock_with_id(txt.strip())
                cht["id_list"].append(ms["reply_to_message_id"])
                cht["txt"].append(txt_rep.replace('\u200c', ' '))
#                 print(cht["id_list"])

    elif if_stock_included(txt):
#         print("if_included_ch",txt)
        txt_rep = replace_stock_with_id(txt.strip())
        chat_list.append({"id_list": [ms['id']], "txt": [
                         txt_rep.replace('\u200c', ' ')]})

# print(chat_list)
for i in chat_list:
    print(i)
    print("***")
# Out:
# CHATLIS__ [{'id_list': [65686], 'txt': ['<3ulz>\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\n در آستانه صف خرید به دلیل رشد 50 درصدی متوقف شد\
# ...

# %%
import tiktoken
enc = tiktoken.get_encoding("cl100k_base")
assert enc.decode(enc.encode("hello world")) == "hello world"

# To get the tokeniser corresponding to a specific model in the OpenAI API:
enc = tiktoken.encoding_for_model("gpt-4")
enc.encode_batch
enc.encode("hello world")
# Out:
# [15339, 1917]

# %%
chat_list
# Out:
# [{'id_list': [65686],
# ...

# %%
if( token_count + chat_tokens_count > 4096 or i+1 == len(chanell)):
  print('')

# %%
# @ BOUNDS : [] 
chat_list
telegram_chanells=[chat_list,chat_list]
enc = tiktoken.get_encoding("cl100k_base")
# enc.encode("hello world")
channels_limit_bound=[]
for chanell in telegram_chanells:
    chanell_bound=[]
    token_count=0
    i=0
#     for (i,chat) in enumerate(chanell):
    while i < len(chanell):
        chat=chanell[i]
        chat_txt="\n".join(chat['txt'])
        chat_tokens_count = len(enc.encode(chat_txt))
#         token_count+=enc.encode(chat['txt'])
#         print(i)
        if( token_count + chat_tokens_count > 4096):
            print( i, len(chanell)  ,  chat_tokens_count,
                  token_count,token_count + chat_tokens_count > 4096 ,i+1 == len(chanell))

            chanell_bound.append(i-1)
            token_count=0
        elif i+1 == len(chanell):
            chanell_bound.append(i)
            token_count=0
            i+=1
#             print(chat_txt)
        else:
            token_count += chat_tokens_count
            i+=1
    channels_limit_bound.append(chanell_bound)
channels_limit_bound
# Out:
# 7 28 233 4000 True False
# 7 28 233 4000 True False
# [[6, 27], [6, 27]]

# %%
# telegram_chanells[0]

# %%
a=[1,2,3,4,5,6,7]
a[2:5]
# Out:
# [3, 4, 5]

# %%
for i,chanell in enumerate(telegram_chanells):
    bound=channels_limit_bound[i]
    prev_bound=0

    for bnd in  channels_limit_bound[i]:
        chanell_res=[]
        if prev_bound ==0:
            chats=concatenate_chanell_chat(chanell[:bnd+1])
            res=request_openai(chats)
            print("if",res["choices"][0]["text"].strip())
            chanell_res.append(res["choices"][0]["text"].strip())
#             req.append(chanell[:bnd+1])
#             print("rev_bound ==0",a[:bnd+1])
        else:
            chats=concatenate_chanell_chat(chanell[prev_bound+1 :bnd+1])
#             request_openai(chats)
            res=request_openai(chats)
            print("else",res["choices"][0]["text"].strip())
            chanell_res.append(res["choices"][0]["text"].strip())

#             print("rev_bound",a[prev_bound+1 : bnd+1])
        prev_bound=bnd
        channels_result.append(chanell_res)    
        
# req
# channels_result[0]
# Out:
# if 36362,
# else 54368,
# if 31115,
# else 74983

# %%
# for ch in channels_result:
#     print(ch[0]["choices"][0]["text"])
channels_result
# Out:
# [['84127,'], ['36362,'], ['54368,'], ['31115,'], ['74983']]

# %%
# a=[1,2,3,4,5,6,2,1,3,4,7]
# # [0:6]
# for i,chanell in enumerate(a):
#     b=0
#     bound=[2,5,7,len(a)-1]
#     req=[]
#     prev_bound=0
# #     while b < len(bound):
#     for b,bnd in enumerate( bound):
# #         if b==0:
# #             print(a[b:bound[b]])
# #         print(a[ b : bound[b]-b ])
# #         print("prev",prev_bound,"bnd",bnd)
#         if prev_bound ==0:
#             request_openai()
#             req.append(a[ prev_bound : bnd+1 ])
# #             print("rev_bound ==0",a[  : bnd+1 ])
#         else:
#             req.append(a[ prev_bound+1 : bnd+1 ])
# #             print("rev_bound",a[ prev_bound+1 : bnd+1])
            
# #         print()
#         prev_bound=bnd
        
            
# #         prev_bound=bound[b]
# #         b+=1
# req
# Out:
# [[1, 2, 3], [4, 5, 6], [2, 1], [3, 4, 7]]

# %%
for i,chanell in enumerate(telegram_chanells):
    for bounds in channels_limit_bound[i]:

# %%
def generate_prompt(animal):
    return """Suggest three names for an animal that is a superhero.

    Animal: Cat
Names: Captain Sharpclaw, Agent Fluffball, The Incredible Feline
Animal: Dog
Names: Ruff the Protector, Wonder Canine, Sir Barks-a-Lot
Animal: {}
Names:""".format(animal.capitalize())

# %%
import os

api_key = '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'
openai.api_key = api_key
openai.Model.retrieve("gpt-3.5-turbo")

def request_openai(prompt):
    return openai.Completion.create(
  model="text-davinci-003",
  prompt="generate some 5 digit and remove any explanaition",
  temperature=1,
    max_tokens=5
)

def concatenate_chanell_chat(chanell):
    chats=""
    for chat in chanell:
        chats+=("\n".join(chat['txt'])+"**")
    return chats
# concatenate_chanell_chat(chat_list)
# import openai
# openai.organization = "YOUR_ORG_ID"
# openai.api_key = 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
# openai.Model.list()
# response = openai.Completion.create(
#   model="text-davinci-003",
#   prompt=generate_prompt(animal),
#   temperature=0.6
# )

# %%
re=openai.Completion.create(
  model="text-davinci-003",
  prompt="generate some 5 digit and remove any explanaition,without any new line",
  temperature=0,
    max_tokens=5
)
re["choices"][0]["text"]
# openai.Completion.create(
#   model="text-davinci-003",
#   prompt="Say this is a test",
#   max_tokens=7,
#   temperature=0
# )
# Out:
# <OpenAIObject text_completion id=cmpl-7DB6WHM6mriUWoNj8Gr8g4aeWmAwH at 0x7fc72c494d60> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\n94567"
#     }
#   ],
#   "created": 1683375304,
#   "id": "cmpl-7DB6WHM6mriUWoNj8Gr8g4aeWmAwH",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 5,
#     "prompt_tokens": 16,
#     "total_tokens": 21
#   }
# }

# %%
re["choices"][0]["text"]
# Out:
# '\n\n94567'

# %%
# resp = openai.Embedding.create(
#     input=["eating food", "I am hungry", "I am traveling" , "exploring new places"],
#     engine="text-similarity-davinci-001")

# %%
# datafile_path = "https://cdn.openai.com/API/examples/data/fine_food_reviews_with_embeddings_1k.csv"  # for your convenience, we precomputed the embeddings
# df = pd.read_csv(datafile_path)
# df.head()

# %%
type(resp['data'])
# respresp['data'][0]['embedding']
resp['data'][0]['embedding']
# Out:
# [-0.006345020141452551,
#  0.00706344423815608,
#  -0.01328766718506813,
#  -0.00896440725773573,
#  -0.007241460960358381,
#  0.005454936996102333,
#  -0.011081533506512642,
#  -0.0026225659530609846,
#  0.006135215051472187,
#  -0.006751915439963341,
#  -0.007012582384049892,
#  0.005693352315574884,
#  0.006160645745694637,
#  0.005308709107339382,
#  0.004329618066549301,
#  -0.012124202214181423,
#  -0.013732708990573883,
#  -0.005906336475163698,
#  -0.012963423505425453,
#  0.0010212112683802843,
#  -0.009771839715540409,
#  -0.002686143387109041,
#  0.017394764348864555,
#  0.006033491343259811,
#  0.00740676186978817,
#  0.005324603524059057,
#  0.009161497466266155,
#  0.0003047739446628839,
#  -0.011431208811700344,
#  0.0058681899681687355,
#  -0.015042402781546116,
#  -0.002210902515798807,
#  0.0037796739488840103,
#  -0.007928096689283848,
#  -0.013580122962594032,
#  -0.0039036497473716736,
#  0.010859012603759766,
#  -0.0058046127669513226,
#  0.004355048760771751,
# ...

# %%
df["babbage_search"] = df.babbage_search.apply(eval).apply(np.array)
df["babbage_similarity"] = df.babbage_similarity.apply(eval).apply(np.array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df["babbage_search"] = df.babbage_search.apply(eval).apply(np.array)
#       2 df["babbage_similarity"] = df.babbage_similarity.apply(eval).apply(np.array)
#
# NameError: name 'df' is not defined

# %%
# lis=[]
# for ms in data['messages']:
# #     print(ms['id'])
# #     print(ms['text'])
#     txt=ms['text']
    
# #     res = [ele for ele in kw if(ele in ms['text'])]
#     if type(txt)==str:
#         klis=[]
#         for k in kw:
#             if k in txt.split():
#                 print("****************** TRUE",k)
#                 print(txt)
#                 print("***************** ")
#                 klis.append(k)
#         if len(klis)!= 0:
#             lis.append( {"id":ms['id'],"kw":klis,"txt":txt  })


                
# #     print("Does string contain any list element : " + str(bool(res)))

# %%
# sorted_list = sorted(lis, key=lambda x: x['id'])
# # sorted_list
# for dic in sorted_list:
#     print('**')
#     print(dic['txt'])

# %%
# dup_list=[]
# prev_dic=None

# for i,dic in enumerate(sorted_list):
#     if prev_dic and dic['id']==prev_dic['id']:
#         print('hi')
#         for k in prev_dic['kw']:
#             dic['kw'].append(k)
# #         dic['kw']
# #         dic['kw'].extend(*prev_dic['kw'])
#         dup_list.append(i-1)
#     prev_dic=dic
# print(dup_list)

# %%
# sorted_list[130:135]

# %%
# df=pd.DataFrame(lis)
# df.head(100)
# df.to_csv('./chat.csv')

# %% [markdown]
# # PROMPT
# <!-- first translate these chats in English for your self , then make inferences from these chats that people suggest what stocks are going to raise and people are going to buy and what stocks are going to fall. also list stocks that peaple suggest to hold in hold list. ignore people questions about stocks and list stocknames ignored list.
# just list the output like these:
# buy : ['stock_name']
# sell: ['stock_name']
# ignored:[]
# hold :[]
# سلام
# سهم ونیرو تا چقدر بالا میره ؟
# لطفا راهنمایی کنید وقت خرید هست یا نه ؟
# **
# وپارس تحلیل،،،میشه خرید زد
# **
# بکام خوبیهای فروش
# **
# سلام برای خرید غگیلا کی باید سفارش ثبت کرد ؟!
# **
# برای کارگزاری آگاه
# غگیلا خرید زدیم چهارشنبه ک نگرفت برای عرضه اولیه ، الان باید چه کرد ؟
# خرید مجدد میخواد یا خودشون میگیرن؟
# **
# وملل واسه خرید
# **
# سلام تارگت وتحليل كترام لطفاممنونم ازلطفتون
# **
# سلام شش تا میشه خرید الان
# **
# کترام فروش یا نگهداری
# **
# دوستان برا خرید چی خوبه ؟
# **
# برای خرید کوتاه مدت چی خوبه
# **
# قشرین در کف کانال.
# **
# فملی واسه خرید چطوره؟؟؟؟
# **
# چرا همه از ریزش بورس میگن ولی هیچکس دلیل علمی ملموسی ارائه نمیده؟
# همه میگن من میدونم که اینجوری میشه یه بار هم سال ۹۲ اینجوری شد.
# شاید بازار بورس را بتوان به دریاچه ای تشبیه کرد که خیلی ها برای صید به این دریا پا گذاشته اند .
# ورودی نقدینگی را میتوان دبی ورودی این دریاچه تشبیه کرد و خروج نقدینگی را دبی خروجی آن.
# حال عمق این دریاچه چقدر است؟
# دولت چقدر میخواهد آن را عمیق تر و وسیعتر کند؟
# ظرفیت و گنجایش این دریاچه چقدر است؟
# مقاومت سد چقدر است و در چه شرایطی امکان دارد سد بشکند؟
#
# حال با توجه به پارامترهای عمق و وسعت و مقاومت سد چگونه باید دبی ورودی و خروجی دریاچه را تنظیم کرد تا دریا متلاطم نشود و همه بتوانند صید خوبی داشته باشند و باز هم برای صید به دریا برگردند و یا اصلا آنقدر صیادی لذت بخش باشد که کسی دریا را ترک نکند .
#
# کاش این همه مغز متفکر و دانشمند بازار سرمایه برای این مساله راهکاری ارائه دهند .
# **
# سلام.چطوری میشه اوراق واسه وام مسکن خرید از بورس
# **
# سلام صبا نگهداری یا فروش
# **
# سلام.
# خفنر فروش یا سهامداری؟
# **
# رانفور مقاومت و حمایت
# **
# شگویا نگهداری یا فروش
# **
# ومهان و وبانک نگهداری یا فروش
# **
# غدیس حمایت خطوط سفید را دارد.
# **
# هدف ذوب بلند مدتی لطفا
# **
# سلام
# سهم غگل واسه خرید نظرتون لطفا
# **
# سلام کلوند رو با دید میان مدت به قیمت ۳۳۲۷۹ ریال خریدم امکان داره تحلیل کنید و بفرمایید که ارزش سرمایه‌گذاری داره؟ونفت رو هم تحلیل کنید ممنون میشم
# **
# وقتی یه نفر سهام یک شرکت رو میخره میشه سهامدار شرکت
# بعبارتی مالک قسمتی از اون شرکت هست
# حالا نمیدونم چرا طرف تا یکی میگه "پِخ" سریع از دم کل سبدش رو با رنج منفی و 10 درصد زیر پایانی حراج میکنه . یعنی طرف سهمشو در منفی شنبه آینده داره میفروشه 😂
# یعنی طوری میفروشه انگار خمپاره خورده وسط بورس🤪
# اصلا انگار نه انگار که مالک شرکت هست !!
#
# من نمیدونم الان اگه بهش بگن قیمت ملک 5 درصد کشیده پایین همین شخص سریع میپره سره گاو صندوق سند خونه رو برمیداره میره املاکی و 10 درصد زیر قیمت حراج میکنه ؟؟؟!!!🤔
#
# اصلا نفهمیده ماهیت بورس و معنی سرمایگذاری چی هست ، فقط دلش خوشه 2 تومنش شده 3 تومن چندرقاز گیرش اومده .
#
# اقای زرنگ تو شنبه میای همین سهم رو توی صف خرید التماس میکنی
# **
# سلام
# خرید برای بلند مدت پیشنهاد میدین؟؟
# **
# دهدشت ارزش خرید نداره
# **
# بنظرتون باز خرید انجام بدم؟
# **
# تحلیل شکلر و چه قیمتی حمایت میشه؟
# **
# سلام وقت فروش شستا کیه؟
# **
# دزهراوی
# هدف لطفا
# **
# سلام نوری خرید خوبه
# **
# با درود و احترام
# ومهان آپدیت
# ممنون میشم نقطه مقاومت و نقطه حمایت را بنویسید
# ** -->

# %%
# for i,val in enumerate('كهمدا'):
# #     for j in   'کهمدا':
# #         print(i,i==j)
#     print('کهمدا'[i],ord('کهمدا'[i]),ord('كهمدا'[i]),i==j)

# %%
# !pip3 install parsivar

# %%
# from parsivar import Normalizer
# my_normalizer = Normalizer()
# ko='كهمدا'
# ks='کهمدا'
# kko=my_normalizer.normalize(ko)
# kks=my_normalizer.normalize(ks)
# # print(my_normalizer.normalize(ko)==my_normalizer.normalize(ks))
# # print(my_normalizer.normalize(ks))
# for i,val in enumerate(ko):
# #     for j in   'کهمدا':
# #         print(i,i==j)
#     print(val,ord(val),ord(ks[i]),val==ks[i])
